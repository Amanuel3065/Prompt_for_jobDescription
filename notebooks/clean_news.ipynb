# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import STOPWORDS,WordCloud
#from gensim import corpora
import pandas as pd
import statistics
import string
import os
import re
import sys
import inspect
import numpy as np

# %%
news = pd.read_csv('../data/Example_data.csv')
news.head()
# Out:
#                        Domain  \
# 0         rassegnastampa.news
# 1                 twitter.com
# 2             atpe-tchad.info
# 3  badbluetech.bitnamiapp.com
# 4           kryptogazette.com
#
#                                                Title  \
# 0  Boris Johnson using a taxpayer-funded jet for ...
# 1  Stumbled across an interesting case, a woman f...
# 2  Marché Résines dans les peintures et revêtemen...
# 3        AI drives data analytics surge, study finds
# 4  Triacetin Vertrieb Markt 2021: Globale Unterne...
#
#                                          Description  \
# 0  …often trigger a protest vote that can upset…t...
# 1  Stumbled across an interesting case, a woman f...
# 2  …COVID-19…COVID…COVID…COVID-19 et Post COVID…C...
# 3  …hate raiders' linked to automated harassment ...
# 4  …Abschnitten und Endanwendungen / Organisation...
#
#                                                 Body  \
# 0  Boris Johnson using a taxpayer-funded jet for ...
# ...

# %%
df = pd.DataFrame(columns=['Title', 'Description', 'Body', 'Analyst_Average_Score'])

df['Title'] =  news['Title'].to_list()
df['Description'] = news['Description'].to_list()
df['Body'] = news['Body'].to_list()
df['Analyst_Average_Score'] = news['Analyst_Average_Score'].to_list()

df.head()
# Out:
#                                                Title  \
# 0  Boris Johnson using a taxpayer-funded jet for ...
# 1  Stumbled across an interesting case, a woman f...
# 2  Marché Résines dans les peintures et revêtemen...
# 3        AI drives data analytics surge, study finds
# 4  Triacetin Vertrieb Markt 2021: Globale Unterne...
#
#                                          Description  \
# 0  …often trigger a protest vote that can upset…t...
# 1  Stumbled across an interesting case, a woman f...
# 2  …COVID-19…COVID…COVID…COVID-19 et Post COVID…C...
# 3  …hate raiders' linked to automated harassment ...
# 4  …Abschnitten und Endanwendungen / Organisation...
#
#                                                 Body  Analyst_Average_Score
# 0  Boris Johnson using a taxpayer-funded jet for ...                    0.0
# 1  Stumbled across an interesting case, a woman f...                    0.0
# 2  Le rapport d’étude de marché Résines dans les ...                    0.0
# ...

# %%
df.to_csv('../data/Example_data.csv', index=False)
print('Model Ready Data Successfully Saved.!!!')
# Out:
# Model Ready Data Successfully Saved.!!!
